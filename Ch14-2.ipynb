# %% [markdown]
# <h1>학습셋의 자동 중단</h1><br>
# 학습이 진행될수록 학습셋의 정확도는 올라가지만 과적합으로 인해 테스트셋의 실험 결과는 점점 나빠지기 때문에<br>
# 테스트셋 오차가 줄어들지 않으면 실험을 멈추게 해주는 케라스 함수 <strong>EarlyStopping()</strong>함수를 사용하자!

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping

import pandas as pd
import numpy
import os
import matplotlib.pyplot as plt
import tensorflow as tf

seed = 0
numpy.random.seed(seed)
tf.set_random_seed(seed)

df_fre = pd.read_csv('../dataset/wine.csv', header=None)
df = df_fre.sample(frac=0.15)

dataset = df.values
X = dataset[:, 0:12]
Y = dataset[:,12]

model = Sequential()
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)
    

modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

early_stopping_callback = EarlyStopping(monitor= 'val_loss', patience=100)

model.fit(X, Y, validation_split= 0.2, epochs=2000, batch_size=500, callbacks=[early_stopping_callback,checkpointer])
# Out:
# Train on 780 samples, validate on 195 samples
# Epoch 1/2000
# 780/780 [==============================] - 0s 402us/step - loss: 0.5458 - acc: 0.7654 - val_loss: 0.4874 - val_acc: 0.7744
#
# Epoch 00001: val_loss improved from inf to 0.48741, saving model to ./model/01-0.4874.hdf5
# Epoch 2/2000
# 780/780 [==============================] - 0s 5us/step - loss: 0.4903 - acc: 0.7654 - val_loss: 0.4617 - val_acc: 0.7744
#
# Epoch 00002: val_loss improved from 0.48741 to 0.46169, saving model to ./model/02-0.4617.hdf5
# Epoch 3/2000
# 780/780 [==============================] - 0s 5us/step - loss: 0.4553 - acc: 0.7641 - val_loss: 0.4354 - val_acc: 0.7744
#
# Epoch 00003: val_loss improved from 0.46169 to 0.43538, saving model to ./model/03-0.4354.hdf5
# Epoch 4/2000
# 780/780 [==============================] - 0s 8us/step - loss: 0.4243 - acc: 0.7654 - val_loss: 0.4211 - val_acc: 0.7641
#
# Epoch 00004: val_loss improved from 0.43538 to 0.42113, saving model to ./model/04-0.4211.hdf5
# ...

# %% [markdown]
# 테스트셋 오차가 그 이상 줄어들지 않자 실험이 중단된다!<br>
# model.fit의 인자에 콜백함수 <strong>early_stopping_callback</strong>을 넣었기 때문에 조건이 주어지면 중단!<br>
# Epoch 706때 모델을 저장한 후 테스트셋의 오차(val_loss)가 줄어들지 않자 중단!
